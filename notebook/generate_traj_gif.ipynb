# %%
import os
import matplotlib.pyplot as plt
from units.visualize import visualize_and_animate_trajectory
BOND_CONTROL_PARAMS = {
        'covalent_factor': 1.2, 
        'force_bond': [],
        'force_nobond': []
    }

# %%
xyz_traj_file = "../xyz_traj/b7_s3.xyz"
gif_file = f"../gif/{os.path.basename(xyz_traj_file)[:-4]}.gif"
final_img = visualize_and_animate_trajectory(
            xyz_file_path=xyz_traj_file,
            output_gif_path=gif_file,
            bond_params=BOND_CONTROL_PARAMS,
            selected_frames=list(range(0,1001,10)),
            elev=90, azim=90, roll=-95,
            fps=30
        )
# Out:
# Loading trajectory file: ../xyz_traj/b7_s3.xyz
# Total 101 frame(s), Starting frame-by-frame plotting...
#   - Processing frame 100/101...
# All 101 frames plotted. Generating GIF...
# 🎉 Animation successfully saved to: ../gif/b7_s3.gif
# Temporary files cleaned up.

# %%
plt.matshow(final_img)
